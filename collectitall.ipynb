# %%
import pandas as pd

# %%
classes = pd.read_csv('sky_fall_2022_classes.csv')

# %%
classes.columns = classes.iloc[1]

# %%
classes
# Out:
# 1       CRN  Subj  Crse  Sec                           Title        Dates  \
# 0       NaN   NaN   NaN  NaN                             NaN          NaN
# 1       CRN  Subj  Crse  Sec                           Title        Dates
# 2       NaN   NaN   NaN  NaN                             NaN          NaN
# 3     80005  ACTG   100   JA           Accounting Procedures  08/17-12/14
# 4     80006  ACTG   100  OLH           Accounting Procedures  08/17-12/17
# ...     ...   ...   ...  ...                             ...          ...
# 1154  97683  WELL   723  OSH          Ayurvedic Aromatherapy  10/17-12/10
# 1155  95021  WELL   725  OLH  Consciousness/Intnt/Meditation  08/17-12/17
# 1156  95926  WELL   742  OLH   Herbal/Botanical Med/Ethnobot  08/17-12/17
# 1157  97696  WELL   743  OLH   Holistic Nutrition/Functional  08/17-12/17
# 1158    NaN   NaN   NaN  NaN                             NaN          NaN
#
# 1     Days         Time               Instructor  Units     NaN    Bldg  \
# ...

# %%
classes.drop(classes['CRN' == 'NaN'].index)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3799             try:
# -> 3800                 return self._engine.get_loc(casted_key)
#    3801             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# ...
