# %%
'''
Test file for main to add new features:
Features include additional filters by student registration: class name, CRN, DEPT
Will have minimal comments b/c it's a test file
'''
import pandas as pd
import os

### Load session logs csv file and apply first phase of data cleaning on it ###
cwd = os.getcwd()
df = pd.read_csv(cwd + "/(Enc)Data - Coded_SessionLogs.csv")

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 20)

df.columns = [col.lower() for col in df.columns]

df = df.rename(columns={'unnamed: 0' : 'id'})
df = df.rename(columns={'"name"' : 'encrypted_name'})
df = df.rename(columns={'services' : 'service'})
df = df.rename(columns={'signintime' : 'sign_in_time'})
df = df.rename(columns={'signouttime' : 'sign_out_time'})
df = df.rename(columns={'period' : 'duration'})

filt = (df['service'] != 'No Sessions')
df = df[filt]

df['sign_in_time'] = pd.to_datetime(df['sign_in_time'])
df['sign_out_time'] = pd.to_datetime(df['sign_out_time'])
df.insert(7, 'hour_in', df['sign_in_time'].apply(lambda x : x.hour))
df.insert(8, 'hour_out', df['sign_out_time'].apply(lambda x : x.hour))
df.insert(9, 'weekday', df['sign_in_time'].apply(lambda x : x.weekday()))

filt = (
    (df['hour_in'] >= 8) & (df['hour_in'] <= 20) &
    (df['hour_out'] >= 8) & (df['hour_out'] <= 20) & (df['weekday'] <= 4)
)
df = df[filt]

df.reset_index(drop=True, inplace=True)

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 20)

# %%
df['service'].unique()
# Out:
# array(['In-person Tutoring (STEM Center)', 'Space to Study (STEM Center)',
#        'Open Lab (TBA Hours)', 'Virtual Tutoring',
#        'Space to Study (MESA)', 'Workshop Attendance', 'Fabrication Lab'],
#       dtype=object)

# %%
df
# Out:
#         id       encrypted_name                           service  \
# 0        1               Shayla  In-person Tutoring (STEM Center)
# 1        2               Shayla  In-person Tutoring (STEM Center)
# 2        3               Shayla      Space to Study (STEM Center)
# 3        4               Shayla  In-person Tutoring (STEM Center)
# 4        5               Shayla      Space to Study (STEM Center)
# ...    ...                  ...                               ...
# 8042  9696  Non-STEM Registered      Space to Study (STEM Center)
# 8043  9697  Non-STEM Registered      Space to Study (STEM Center)
# 8044  9698  Non-STEM Registered      Space to Study (STEM Center)
# 8045  9699  Non-STEM Registered      Space to Study (STEM Center)
# 8046  9700  Non-STEM Registered      Space to Study (STEM Center)
#
#                                     course        sign_in_time  \
# 0     [MATH-252]Calcu/Analytic Geometry II 2022-10-07 09:05:00
# 1     [MATH-252]Calcu/Analytic Geometry II 2022-10-05 11:17:00
# 2                                      NaN 2022-09-28 09:03:00
# 3     [MATH-252]Calcu/Analytic Geometry II 2022-09-21 09:50:00
# 4                                      NaN 2022-09-19 14:11:00
# ...                                    ...                 ...
# 8042                                   NaN 2022-08-18 14:58:00
# 8043                                   NaN 2022-08-18 13:05:00
# 8044                                   NaN 2022-08-17 11:03:00
# 8045                                   NaN 2022-08-17 10:27:00
# 8046                                   NaN 2022-08-17 10:29:00
#
#            sign_out_time  duration  hour_in  hour_out  weekday          tutor
# 0    2022-10-07 09:16:00  00:11:00        9         9        4  Thiri Wai Wai
# 1    2022-10-05 11:59:00  00:42:00       11        11        2     Hilary Lin
# 2    2022-09-28 10:06:00  01:03:00        9        10        2            NaN
# 3    2022-09-21 10:05:00  00:15:00        9        10        2  Thiri Wai Wai
# 4    2022-09-19 17:41:00  03:30:00       14        17        0            NaN
# ...                  ...       ...      ...       ...      ...            ...
# 8042 2022-08-18 17:53:00  02:55:00       14        17        3            NaN
# 8043 2022-08-18 13:48:00  00:43:00       13        13        3            NaN
# 8044 2022-08-17 12:56:00  01:53:00       11        12        2            NaN
# 8045 2022-08-17 10:50:00  00:23:00       10        10        2            NaN
# 8046 2022-08-17 10:50:00  00:21:00       10        10        2
#
# [8047 rows x 11 columns]

# %%
# Import registration file and do dirty cleaning
df_reg = pd.read_csv(cwd + "/(Enc)Data - Coded_Registration.csv")
df_reg.columns = [col.lower().replace(' ', '_') for col in df_reg.columns] # rename columns
df_reg['course_dept'] = df_reg['course_dept'].apply(lambda x : x.strip()) # strip white space

# Fix type inconsistencies - convert ints to string
df_reg['crn'] = df_reg['crn'].astype(str)
df_reg['course_num'] = df_reg['course_num'].astype(str)

# %%
df_reg
# Out:
#       unnamed:_0 encrypted_name    crn course_dept course_num
# 0              0           Jojo  97649        MATH        200
# 1              1         Shayla  95003        ENGR        100
# 2              2         Shayla  97251        IDST        105
# 3              3         Shayla  96263        MATH        252
# 4              4       Galileah  97400        ELEC        231
# ...          ...            ...    ...         ...        ...
# 2751        2751          Jeong  80158        BIOL        130
# 2752        2752          Jeong  91704        CHEM        410
# 2753        2753          Bansi  95751        CHEM        210
# 2754        2754     Abdulazeez  80168        BIOL        250
# 2755        2755       Stefanie  96986        MATH        222
#
# [2756 rows x 5 columns]

# %%
# Merge registration and sessionlog CSV files
course_dept_col = df['course'].str.extract(r'^\[(.+)-[0-9]+\.?[0-9]\]')  # get course_dept w/ regex -> a one col df
course_num_col  = df['course'].str.extract(r'^\[.+-([0-9]+\.?[0-9])\]')  # get course_num w/ regex
df.insert(3, 'course_dept', course_dept_col)
df.insert(4, 'course_num', course_num_col)

# %%
df
# Out:
#         id       encrypted_name                           service course_dept  \
# 0        1               Shayla  In-person Tutoring (STEM Center)        MATH
# 1        2               Shayla  In-person Tutoring (STEM Center)        MATH
# 2        3               Shayla      Space to Study (STEM Center)         NaN
# 3        4               Shayla  In-person Tutoring (STEM Center)        MATH
# 4        5               Shayla      Space to Study (STEM Center)         NaN
# ...    ...                  ...                               ...         ...
# 8042  9696  Non-STEM Registered      Space to Study (STEM Center)         NaN
# 8043  9697  Non-STEM Registered      Space to Study (STEM Center)         NaN
# 8044  9698  Non-STEM Registered      Space to Study (STEM Center)         NaN
# 8045  9699  Non-STEM Registered      Space to Study (STEM Center)         NaN
# 8046  9700  Non-STEM Registered      Space to Study (STEM Center)         NaN
#
#      course_num                                course        sign_in_time  \
# 0           252  [MATH-252]Calcu/Analytic Geometry II 2022-10-07 09:05:00
# 1           252  [MATH-252]Calcu/Analytic Geometry II 2022-10-05 11:17:00
# 2           NaN                                   NaN 2022-09-28 09:03:00
# 3           252  [MATH-252]Calcu/Analytic Geometry II 2022-09-21 09:50:00
# 4           NaN                                   NaN 2022-09-19 14:11:00
# ...         ...                                   ...                 ...
# 8042        NaN                                   NaN 2022-08-18 14:58:00
# 8043        NaN                                   NaN 2022-08-18 13:05:00
# 8044        NaN                                   NaN 2022-08-17 11:03:00
# 8045        NaN                                   NaN 2022-08-17 10:27:00
# 8046        NaN                                   NaN 2022-08-17 10:29:00
#
#            sign_out_time  duration  hour_in  hour_out  weekday          tutor
# 0    2022-10-07 09:16:00  00:11:00        9         9        4  Thiri Wai Wai
# 1    2022-10-05 11:59:00  00:42:00       11        11        2     Hilary Lin
# 2    2022-09-28 10:06:00  01:03:00        9        10        2            NaN
# 3    2022-09-21 10:05:00  00:15:00        9        10        2  Thiri Wai Wai
# 4    2022-09-19 17:41:00  03:30:00       14        17        0            NaN
# ...                  ...       ...      ...       ...      ...            ...
# 8042 2022-08-18 17:53:00  02:55:00       14        17        3            NaN
# 8043 2022-08-18 13:48:00  00:43:00       13        13        3            NaN
# 8044 2022-08-17 12:56:00  01:53:00       11        12        2            NaN
# 8045 2022-08-17 10:50:00  00:23:00       10        10        2            NaN
# 8046 2022-08-17 10:50:00  00:21:00       10        10        2
#
# [8047 rows x 13 columns]

# %%
### We added course_num & course_dept. Now we want to add CRN to this DataFrame - but there's a problem ###
# Make empty Series (list) of CRN - we'll get CRN from registration CSV file, then add here
crn_col = pd.Series(index=range(df.shape[0]), dtype=float)  # empty series

# %%
# Test
filt = (
    (df_reg['encrypted_name'] == 'Jojo') &
    (df_reg['course_dept'] == 'MATH')
)
df_reg[filt]['crn']
### PROBEM WITH DATA TYPES HERE BETWEEN SESSIONLOGS DF AND REGISTRATION DF FOR COLUMNS course_name & course_num
# Out:
# 0    97649
# Name: crn, dtype: object

# %%
# Iteratively add CRN to Series to be added to df. Probably .merge() is faster
for idx, row in df.iterrows():
    # Get CRN if there is a course provided for tutoring in the sessionlog
    # If the course is 'NaN', that means that session was not for tutoring, and ignore b/c there's no CRN
    if not pd.isna(df.at[idx, 'course']):
        print(f"Index: {idx}") # Debug test
        # Get session information from session logs
        encrypted_name = row['encrypted_name']  # from sessionlogs df
        course_dept    = row['course_dept']
        course_num     = row['course_num']
        
        # Filter series of registration data that matches the particular session info
        filt = (
            (encrypted_name == df_reg['encrypted_name']) &
            (course_dept    == df_reg['course_dept']) &
            (course_num     == df_reg['course_num'])  # bad code here, need fix later, prob from above comment
        )
        
        # Check for errors
        # Try to get the CRN from registration with the 'filter'
        try:
            crn = df_reg[filt]['crn'].iloc[0]
        except:
            if df_reg[filt].shape[0] != 1:
                # There were no CRNs in registration that matched the session info
                # This is "Tamarsha's Case" - a student that got tutoring for a course but ended up
                # dropping that course. This is because the student is no longer enrolled in the course
                # they got tutoring for, and this is based on the time the registration data was downloaded
                print("PROBLEM: THERE WASN'T ONE MATCH FOR SESSION AND STUDENT'S CRN")
            else:
                # No other case has been detected
                print("There are multiple CRNs that satisfy the criteria")
            # Set CRN to 'Dropped' instead
            crn = 'Dropped'
            # QUESTION: What's the difference btwn'Non-STEM Registered' and Tamarsha's case?
            # Tamarsha's edge case: dropped a class she got tutoring for -> can't get its CRN
            # What is 'Non-STEM Registered' again?
            #
            # 'No Sessions' == Students taking STEM class(es) that haven't been to STEM Center (Dropped all rows)
            # 'Non-STEM Registered' == A student who showed up in our Session Logs,
            #  but did not show up in the registration csv file. ***Why is this?***
            #  Tamarsha's case == Student got tutoring for a class that was later dropped (Set CRN to 'Dropped')
            
            # With this method, 'Non-STEM Registered' sessions will be preserved and included in the df.
            # However, all 'Non-STEM Registered' sessions that were for tutoring will all be marked 'Dropped'
            
            # Another concern: There are 41 sessions where folks got tutoring for a course in the LSKL dept,
            # yet in registration nobody is taking a course in the LSKL dept. Why is this? For some of the
            # less popular courses (not particularly all STEM), students are getting tutoring for them, yet
            # they aren't showing up in the registration. Should we just ignore these b/c they aren't very useful?
            
        print(df_reg[filt])
        print()
        
        crn_col[idx] = crn
# Out:
# Index: 0
#    unnamed:_0 encrypted_name    crn course_dept course_num
# 3           3         Shayla  96263        MATH        252
#
# Index: 1
#    unnamed:_0 encrypted_name    crn course_dept course_num
# 3           3         Shayla  96263        MATH        252
#
# Index: 3
#    unnamed:_0 encrypted_name    crn course_dept course_num
# 3           3         Shayla  96263        MATH        252
#
# Index: 11
#    unnamed:_0 encrypted_name    crn course_dept course_num
# 5           5        Georgiy  92921        BIOL        240
#
# Index: 12
#    unnamed:_0 encrypted_name    crn course_dept course_num
# 5           5        Georgiy  92921        BIOL        240
#
# Index: 13
#    unnamed:_0 encrypted_name    crn course_dept course_num
# 5           5        Georgiy  92921        BIOL        240
#
# Index: 14
#    unnamed:_0 encrypted_name    crn course_dept course_num
# 5           5        Georgiy  92921        BIOL        240
#
# Index: 15
#    unnamed:_0 encrypted_name    crn course_dept course_num
# 5           5        Georgiy  92921        BIOL        240
#
# Index: 16
#    unnamed:_0 encrypted_name    crn course_dept course_num
# 5           5        Georgiy  92921        BIOL        240
#
# Index: 17
#    unnamed:_0 encrypted_name    crn course_dept course_num
# 5           5        Georgiy  92921        BIOL        240
#
# Index: 18
#    unnamed:_0 encrypted_name    crn course_dept course_num
# 5           5        Georgiy  92921        BIOL        240
#
# Index: 19
#    unnamed:_0 encrypted_name    crn course_dept course_num
# 5           5        Georgiy  92921        BIOL        240
#
# Index: 20
#    unnamed:_0 encrypted_name    crn course_dept course_num
# 5           5        Georgiy  92921        BIOL        240
#
# Index: 21
#    unnamed:_0 encrypted_name    crn course_dept course_num
# 5           5        Georgiy  92921        BIOL        240
#
# Index: 22
#    unnamed:_0 encrypted_name    crn course_dept course_num
# 5           5        Georgiy  92921        BIOL        240
#
# Index: 23
#    unnamed:_0 encrypted_name    crn course_dept course_num
# 5           5        Georgiy  92921        BIOL        240
#
# Index: 24
#    unnamed:_0 encrypted_name    crn course_dept course_num
# 5           5        Georgiy  92921        BIOL        240
#
# Index: 25
#    unnamed:_0 encrypted_name    crn course_dept course_num
# 5           5        Georgiy  92921        BIOL        240
#
# Index: 26
#    unnamed:_0 encrypted_name    crn course_dept course_num
# 5           5        Georgiy  92921        BIOL        240
#
# Index: 27
#    unnamed:_0 encrypted_name    crn course_dept course_num
# 5           5        Georgiy  92921        BIOL        240
#
# Index: 28
#    unnamed:_0 encrypted_name    crn course_dept course_num
# 5           5        Georgiy  92921        BIOL        240
#
# Index: 29
#    unnamed:_0 encrypted_name    crn course_dept course_num
# 5           5        Georgiy  92921        BIOL        240
#
# Index: 30
#    unnamed:_0 encrypted_name    crn course_dept course_num
# 8           8         Spicie  80165        BIOL        240
#
# Index: 31
#    unnamed:_0 encrypted_name    crn course_dept course_num
# 8           8         Spicie  80165        BIOL        240
#
# Index: 32
#    unnamed:_0 encrypted_name    crn course_dept course_num
# 8           8         Spicie  80165        BIOL        240
#
# Index: 33
#    unnamed:_0 encrypted_name    crn course_dept course_num
# 8           8         Spicie  80165        BIOL        240
#
# Index: 34
#    unnamed:_0 encrypted_name    crn course_dept course_num
# 8           8         Spicie  80165        BIOL        240
#
# Index: 35
#    unnamed:_0 encrypted_name    crn course_dept course_num
# 8           8         Spicie  80165        BIOL        240
#
# Index: 36
#    unnamed:_0 encrypted_name    crn course_dept course_num
# 8           8         Spicie  80165        BIOL        240
#
# Index: 37
#    unnamed:_0 encrypted_name    crn course_dept course_num
# 8           8         Spicie  80165        BIOL        240
#
# Index: 38
#    unnamed:_0 encrypted_name    crn course_dept course_num
# 8           8         Spicie  80165        BIOL        240
#
# Index: 39
#    unnamed:_0 encrypted_name    crn course_dept course_num
# 8           8         Spicie  80165        BIOL        240
#
# Index: 40
#    unnamed:_0 encrypted_name    crn course_dept course_num
# 8           8         Spicie  80165        BIOL        240
#
# Index: 41
#    unnamed:_0 encrypted_name    crn course_dept course_num
# 8           8         Spicie  80165        BIOL        240
#
# Index: 42
#    unnamed:_0 encrypted_name    crn course_dept course_num
# 8           8         Spicie  80165        BIOL        240
#
# Index: 43
#    unnamed:_0 encrypted_name    crn course_dept course_num
# 8           8         Spicie  80165        BIOL        240
#
# Index: 44
#     unnamed:_0 encrypted_name    crn course_dept course_num
# 11          11        Kamdynn  94927        BIOL        240
#
# Index: 45
#     unnamed:_0 encrypted_name    crn course_dept course_num
# 11          11        Kamdynn  94927        BIOL        240
#
# Index: 46
#     unnamed:_0 encrypted_name    crn course_dept course_num
# 11          11        Kamdynn  94927        BIOL        240
#
# Index: 47
#     unnamed:_0 encrypted_name    crn course_dept course_num
# 12          12        Kamdynn  97597        CHEM        410
#
# Index: 48
#     unnamed:_0 encrypted_name    crn course_dept course_num
# 12          12        Kamdynn  97597        CHEM        410
#
# Index: 49
#     unnamed:_0 encrypted_name    crn course_dept course_num
# 11          11        Kamdynn  94927        BIOL        240
#
# Index: 50
#     unnamed:_0 encrypted_name    crn course_dept course_num
# 12          12        Kamdynn  97597        CHEM        410
#
# Index: 51
#     unnamed:_0 encrypted_name    crn course_dept course_num
# 12          12        Kamdynn  97597        CHEM        410
#
# Index: 52
#     unnamed:_0 encrypted_name    crn course_dept course_num
# 11          11        Kamdynn  94927        BIOL        240
#
# Index: 53
#     unnamed:_0 encrypted_name    crn course_dept course_num
# 12          12        Kamdynn  97597        CHEM        410
#
# Index: 54
#     unnamed:_0 encrypted_name    crn course_dept course_num
# 11          11        Kamdynn  94927        BIOL        240
#
# Index: 55
#     unnamed:_0 encrypted_name    crn course_dept course_num
# 12          12        Kamdynn  97597        CHEM        410
#
# Index: 56
#     unnamed:_0 encrypted_name    crn course_dept course_num
# 11          11        Kamdynn  94927        BIOL        240
#
# Index: 57
#     unnamed:_0 encrypted_name    crn course_dept course_num
# 11          11        Kamdynn  94927        BIOL        240
#
# Index: 59
#     unnamed:_0 encrypted_name    crn course_dept course_num
# 11          11        Kamdynn  94927        BIOL        240
#
# Index: 61
#     unnamed:_0 encrypted_name    crn course_dept course_num
# 12          12        Kamdynn  97597        CHEM        410
#
# Index: 63
#     unnamed:_0 encrypted_name    crn course_dept course_num
# 12          12        Kamdynn  97597        CHEM        410
#
# Index: 64
#     unnamed:_0 encrypted_name    crn course_dept course_num
# 12          12        Kamdynn  97597        CHEM        410
#
# Index: 65
#     unnamed:_0 encrypted_name    crn course_dept course_num
# 12          12        Kamdynn  97597        CHEM        410
#
# Index: 66
#     unnamed:_0 encrypted_name    crn course_dept course_num
# 11          11        Kamdynn  94927        BIOL        240
#
# Index: 67
#     unnamed:_0 encrypted_name    crn course_dept course_num
# 12          12        Kamdynn  97597        CHEM        410
#
# Index: 68
#     unnamed:_0 encrypted_name    crn course_dept course_num
# 12          12        Kamdynn  97597        CHEM        410
#
# Index: 70
#     unnamed:_0 encrypted_name    crn course_dept course_num
# 12          12        Kamdynn  97597        CHEM        410
#
# Index: 71
#     unnamed:_0 encrypted_name    crn course_dept course_num
# 12          12        Kamdynn  97597        CHEM        410
#
# Index: 73
#     unnamed:_0 encrypted_name    crn course_dept course_num
# 11          11        Kamdynn  94927        BIOL        240
#
# Index: 74
#     unnamed:_0 encrypted_name    crn course_dept course_num
# 12          12        Kamdynn  97597        CHEM        410
#
# Index: 75
#     unnamed:_0 encrypted_name    crn course_dept course_num
# 11          11        Kamdynn  94927        BIOL        240
#
# Index: 76
#     unnamed:_0 encrypted_name    crn course_dept course_num
# 12          12        Kamdynn  97597        CHEM        410
#
# Index: 77
#     unnamed:_0 encrypted_name    crn course_dept course_num
# 11          11        Kamdynn  94927        BIOL        240
#
# Index: 78
#     unnamed:_0 encrypted_name    crn course_dept course_num
# 11          11        Kamdynn  94927        BIOL        240
#
# Index: 79
#     unnamed:_0 encrypted_name    crn course_dept course_num
# 12          12        Kamdynn  97597        CHEM        410
#
# Index: 80
#     unnamed:_0 encrypted_name    crn course_dept course_num
# 12          12        Kamdynn  97597        CHEM        410
#
# Index: 81
#     unnamed:_0 encrypted_name    crn course_dept course_num
# 11          11        Kamdynn  94927        BIOL        240
#
# Index: 82
#     unnamed:_0 encrypted_name    crn course_dept course_num
# 12          12        Kamdynn  97597        CHEM        410
#
# Index: 83
#     unnamed:_0 encrypted_name    crn course_dept course_num
# 11          11        Kamdynn  94927        BIOL        240
#
# Index: 84
#     unnamed:_0 encrypted_name    crn course_dept course_num
# 11          11        Kamdynn  94927        BIOL        240
#
# Index: 85
#     unnamed:_0 encrypted_name    crn course_dept course_num
# 12          12        Kamdynn  97597        CHEM        410
#
# Index: 86
#     unnamed:_0 encrypted_name    crn course_dept course_num
# 12          12        Kamdynn  97597        CHEM        410
#
# Index: 87
#     unnamed:_0 encrypted_name    crn course_dept course_num
# 18          18          Xaria  80166        BIOL        240
#
# Index: 88
#     unnamed:_0 encrypted_name    crn course_dept course_num
# 18          18          Xaria  80166        BIOL        240
#
# Index: 89
#     unnamed:_0 encrypted_name    crn course_dept course_num
# 18          18          Xaria  80166        BIOL        240
#
# Index: 90
#     unnamed:_0 encrypted_name    crn course_dept course_num
# 18          18          Xaria  80166        BIOL        240
#
# Index: 91
#     unnamed:_0 encrypted_name    crn course_dept course_num
# 18          18          Xaria  80166        BIOL        240
#
# Index: 92
#     unnamed:_0 encrypted_name    crn course_dept course_num
# 18          18          Xaria  80166        BIOL        240
#
# Index: 93
#     unnamed:_0 encrypted_name    crn course_dept course_num
# 18          18          Xaria  80166        BIOL        240
#
# Index: 94
#     unnamed:_0 encrypted_name    crn course_dept course_num
# 18          18          Xaria  80166        BIOL        240
#
# Index: 95
#     unnamed:_0 encrypted_name    crn course_dept course_num
# 18          18          Xaria  80166        BIOL        240
#
# Index: 96
#     unnamed:_0 encrypted_name    crn course_dept course_num
# 18          18          Xaria  80166        BIOL        240
#
# Index: 97
#     unnamed:_0 encrypted_name    crn course_dept course_num
# 23          23         Dulcie  97597        CHEM        410
#
# Index: 98
#     unnamed:_0 encrypted_name    crn course_dept course_num
# 23          23         Dulcie  97597        CHEM        410
#
# Index: 99
#     unnamed:_0 encrypted_name    crn course_dept course_num
# 23          23         Dulcie  97597        CHEM        410
#
# Index: 100
#     unnamed:_0 encrypted_name    crn course_dept course_num
#
#       unnamed:_0 encrypted_name    crn course_dept course_num
# 2727        2727   Jacobmatthew  95003        ENGR        100
#
# Index: 7784
#       unnamed:_0 encrypted_name    crn course_dept course_num
# 2739        2739           Zein  84828        BIOL        240
#
# Index: 7785
#       unnamed:_0 encrypted_name    crn course_dept course_num
# 2739        2739           Zein  84828        BIOL        240
#
# Index: 7786
#       unnamed:_0 encrypted_name    crn course_dept course_num
# 2739        2739           Zein  84828        BIOL        240
#
# Index: 7787
#       unnamed:_0 encrypted_name    crn course_dept course_num
# 2739        2739           Zein  84828        BIOL        240
#
# Index: 7788
#       unnamed:_0 encrypted_name    crn course_dept course_num
# 2739        2739           Zein  84828        BIOL        240
#
# Index: 7789
#       unnamed:_0 encrypted_name    crn course_dept course_num
# 2739        2739           Zein  84828        BIOL        240
#
# Index: 7790
#       unnamed:_0 encrypted_name    crn course_dept course_num
# 2739        2739           Zein  84828        BIOL        240
#
# Index: 7791
#       unnamed:_0 encrypted_name    crn course_dept course_num
# 2739        2739           Zein  84828        BIOL        240
#
# Index: 7792
#       unnamed:_0 encrypted_name    crn course_dept course_num
# 2739        2739           Zein  84828        BIOL        240
#
# Index: 7793
#       unnamed:_0 encrypted_name    crn course_dept course_num
# 2739        2739           Zein  84828        BIOL        240
#
# Index: 7794
#       unnamed:_0 encrypted_name    crn course_dept course_num
# 2739        2739           Zein  84828        BIOL        240
#
# Index: 7795
#       unnamed:_0 encrypted_name    crn course_dept course_num
# 2739        2739           Zein  84828        BIOL        240
#
# Index: 7796
#       unnamed:_0 encrypted_name    crn course_dept course_num
# 2739        2739           Zein  84828        BIOL        240
#
# Index: 7797
#       unnamed:_0 encrypted_name    crn course_dept course_num
# 2739        2739           Zein  84828        BIOL        240
#
# Index: 7798
#       unnamed:_0 encrypted_name    crn course_dept course_num
# 2739        2739           Zein  84828        BIOL        240
#
# Index: 7799
#       unnamed:_0 encrypted_name    crn course_dept course_num
# 2739        2739           Zein  84828        BIOL        240
#
# Index: 7800
#       unnamed:_0 encrypted_name    crn course_dept course_num
# 2739        2739           Zein  84828        BIOL        240
#
# Index: 7801
#       unnamed:_0 encrypted_name    crn course_dept course_num
# 2739        2739           Zein  84828        BIOL        240
#
# Index: 7802
#       unnamed:_0 encrypted_name    crn course_dept course_num
# 2739        2739           Zein  84828        BIOL        240
#
# Index: 7803
#       unnamed:_0 encrypted_name    crn course_dept course_num
# 2739        2739           Zein  84828        BIOL        240
#
# Index: 7804
#       unnamed:_0 encrypted_name    crn course_dept course_num
# 2739        2739           Zein  84828        BIOL        240
#
# Index: 7805
#       unnamed:_0 encrypted_name    crn course_dept course_num
# 2739        2739           Zein  84828        BIOL        240
#
# Index: 7806
#       unnamed:_0 encrypted_name    crn course_dept course_num
# 2739        2739           Zein  84828        BIOL        240
#
# Index: 7807
#       unnamed:_0 encrypted_name    crn course_dept course_num
# 2739        2739           Zein  84828        BIOL        240
#
# Index: 7808
#       unnamed:_0 encrypted_name    crn course_dept course_num
# 2739        2739           Zein  84828        BIOL        240
#
# Index: 7809
#       unnamed:_0 encrypted_name    crn course_dept course_num
# 2739        2739           Zein  84828        BIOL        240
#
# Index: 7810
#       unnamed:_0 encrypted_name    crn course_dept course_num
# 2739        2739           Zein  84828        BIOL        240
#
# Index: 7811
#       unnamed:_0 encrypted_name    crn course_dept course_num
# 2739        2739           Zein  84828        BIOL        240
#
# Index: 7812
#       unnamed:_0 encrypted_name    crn course_dept course_num
# 2739        2739           Zein  84828        BIOL        240
#
# Index: 7813
#       unnamed:_0 encrypted_name    crn course_dept course_num
# 2739        2739           Zein  84828        BIOL        240
#
# Index: 7814
#       unnamed:_0 encrypted_name    crn course_dept course_num
# 2739        2739           Zein  84828        BIOL        240
#
# Index: 7815
#       unnamed:_0 encrypted_name    crn course_dept course_num
# 2739        2739           Zein  84828        BIOL        240
#
# Index: 7816
#       unnamed:_0 encrypted_name    crn course_dept course_num
# 2739        2739           Zein  84828        BIOL        240
#
# Index: 7817
#       unnamed:_0 encrypted_name    crn course_dept course_num
# 2739        2739           Zein  84828        BIOL        240
#
# Index: 7818
#       unnamed:_0 encrypted_name    crn course_dept course_num
# 2739        2739           Zein  84828        BIOL        240
#
# Index: 7819
#       unnamed:_0 encrypted_name    crn course_dept course_num
# 2739        2739           Zein  84828        BIOL        240
#
# Index: 7820
#       unnamed:_0 encrypted_name    crn course_dept course_num
# 2739        2739           Zein  84828        BIOL        240
#
# Index: 7821
#       unnamed:_0 encrypted_name    crn course_dept course_num
# 2739        2739           Zein  84828        BIOL        240
#
# Index: 7822
#       unnamed:_0 encrypted_name    crn course_dept course_num
# 2739        2739           Zein  84828        BIOL        240
#
# Index: 7823
#       unnamed:_0 encrypted_name    crn course_dept course_num
# 2739        2739           Zein  84828        BIOL        240
#
# Index: 7824
#       unnamed:_0 encrypted_name    crn course_dept course_num
# 2739        2739           Zein  84828        BIOL        240
#
# Index: 7825
#       unnamed:_0 encrypted_name    crn course_dept course_num
# 2739        2739           Zein  84828        BIOL        240
#
# Index: 7826
#       unnamed:_0 encrypted_name    crn course_dept course_num
# 2739        2739           Zein  84828        BIOL        240
#
# Index: 7828
#       unnamed:_0 encrypted_name    crn course_dept course_num
# 2752        2752          Jeong  91704        CHEM        410
#
# Index: 7830
#       unnamed:_0 encrypted_name    crn course_dept course_num
# 2751        2751          Jeong  80158        BIOL        130
#
# Index: 7834
#       unnamed:_0 encrypted_name    crn course_dept course_num
# 2752        2752          Jeong  91704        CHEM        410
#
# Index: 7835
#       unnamed:_0 encrypted_name    crn course_dept course_num
# 2752        2752          Jeong  91704        CHEM        410
#
# Index: 7906
# PROBLEM: THERE WASN'T ONE MATCH FOR SESSION AND STUDENT'S CRN
# Empty DataFrame
# Columns: [unnamed:_0, encrypted_name, crn, course_dept, course_num]
# Index: []
#
# Index: 7907
# PROBLEM: THERE WASN'T ONE MATCH FOR SESSION AND STUDENT'S CRN
# Empty DataFrame
# Columns: [unnamed:_0, encrypted_name, crn, course_dept, course_num]
# Index: []
#
# Index: 7908
# PROBLEM: THERE WASN'T ONE MATCH FOR SESSION AND STUDENT'S CRN
# Empty DataFrame
# Columns: [unnamed:_0, encrypted_name, crn, course_dept, course_num]
# Index: []
#
# Index: 7909
# PROBLEM: THERE WASN'T ONE MATCH FOR SESSION AND STUDENT'S CRN
# Empty DataFrame
# Columns: [unnamed:_0, encrypted_name, crn, course_dept, course_num]
# Index: []
#
# Index: 7910
# PROBLEM: THERE WASN'T ONE MATCH FOR SESSION AND STUDENT'S CRN
# Empty DataFrame
# Columns: [unnamed:_0, encrypted_name, crn, course_dept, course_num]
# Index: []
#
# Index: 7937
# PROBLEM: THERE WASN'T ONE MATCH FOR SESSION AND STUDENT'S CRN
# Empty DataFrame
# Columns: [unnamed:_0, encrypted_name, crn, course_dept, course_num]
# Index: []
#
# Index: 7938
# PROBLEM: THERE WASN'T ONE MATCH FOR SESSION AND STUDENT'S CRN
# Empty DataFrame
# Columns: [unnamed:_0, encrypted_name, crn, course_dept, course_num]
# Index: []
#
# Index: 7939
# PROBLEM: THERE WASN'T ONE MATCH FOR SESSION AND STUDENT'S CRN
# Empty DataFrame
# Columns: [unnamed:_0, encrypted_name, crn, course_dept, course_num]
# Index: []
#
# Index: 7940
# PROBLEM: THERE WASN'T ONE MATCH FOR SESSION AND STUDENT'S CRN
# Empty DataFrame
# Columns: [unnamed:_0, encrypted_name, crn, course_dept, course_num]
# Index: []
#
# Index: 7941
# PROBLEM: THERE WASN'T ONE MATCH FOR SESSION AND STUDENT'S CRN
# Empty DataFrame
# Columns: [unnamed:_0, encrypted_name, crn, course_dept, course_num]
# Index: []
#
# Index: 7942
# PROBLEM: THERE WASN'T ONE MATCH FOR SESSION AND STUDENT'S CRN
# Empty DataFrame
# Columns: [unnamed:_0, encrypted_name, crn, course_dept, course_num]
# Index: []
#
# Index: 7943
# PROBLEM: THERE WASN'T ONE MATCH FOR SESSION AND STUDENT'S CRN
# Empty DataFrame
# Columns: [unnamed:_0, encrypted_name, crn, course_dept, course_num]
# Index: []
#
# Index: 7944
# PROBLEM: THERE WASN'T ONE MATCH FOR SESSION AND STUDENT'S CRN
# Empty DataFrame
# Columns: [unnamed:_0, encrypted_name, crn, course_dept, course_num]
# Index: []
#
# Index: 7945
# PROBLEM: THERE WASN'T ONE MATCH FOR SESSION AND STUDENT'S CRN
# Empty DataFrame
# Columns: [unnamed:_0, encrypted_name, crn, course_dept, course_num]
# Index: []
#
# Index: 7946
# PROBLEM: THERE WASN'T ONE MATCH FOR SESSION AND STUDENT'S CRN
# Empty DataFrame
# Columns: [unnamed:_0, encrypted_name, crn, course_dept, course_num]
# Index: []
#
# Index: 7947
# PROBLEM: THERE WASN'T ONE MATCH FOR SESSION AND STUDENT'S CRN
# Empty DataFrame
# Columns: [unnamed:_0, encrypted_name, crn, course_dept, course_num]
# Index: []
#
# Index: 7948
# PROBLEM: THERE WASN'T ONE MATCH FOR SESSION AND STUDENT'S CRN
# Empty DataFrame
# Columns: [unnamed:_0, encrypted_name, crn, course_dept, course_num]
# Index: []
#
# Index: 7949
# PROBLEM: THERE WASN'T ONE MATCH FOR SESSION AND STUDENT'S CRN
# Empty DataFrame
# Columns: [unnamed:_0, encrypted_name, crn, course_dept, course_num]
# Index: []
#
# Index: 7950
# PROBLEM: THERE WASN'T ONE MATCH FOR SESSION AND STUDENT'S CRN
# Empty DataFrame
# Columns: [unnamed:_0, encrypted_name, crn, course_dept, course_num]
# Index: []
#
# Index: 7951
# PROBLEM: THERE WASN'T ONE MATCH FOR SESSION AND STUDENT'S CRN
# Empty DataFrame
# Columns: [unnamed:_0, encrypted_name, crn, course_dept, course_num]
# Index: []
#
# Index: 7952
# PROBLEM: THERE WASN'T ONE MATCH FOR SESSION AND STUDENT'S CRN
# Empty DataFrame
# Columns: [unnamed:_0, encrypted_name, crn, course_dept, course_num]
# Index: []
#
# Index: 7953
# PROBLEM: THERE WASN'T ONE MATCH FOR SESSION AND STUDENT'S CRN
# Empty DataFrame
# Columns: [unnamed:_0, encrypted_name, crn, course_dept, course_num]
# Index: []
#
# Index: 7954
# PROBLEM: THERE WASN'T ONE MATCH FOR SESSION AND STUDENT'S CRN
# Empty DataFrame
# Columns: [unnamed:_0, encrypted_name, crn, course_dept, course_num]
# Index: []
#
# Index: 7955
# PROBLEM: THERE WASN'T ONE MATCH FOR SESSION AND STUDENT'S CRN
# Empty DataFrame
# Columns: [unnamed:_0, encrypted_name, crn, course_dept, course_num]
# Index: []
#
# Index: 7956
# PROBLEM: THERE WASN'T ONE MATCH FOR SESSION AND STUDENT'S CRN
# Empty DataFrame
# Columns: [unnamed:_0, encrypted_name, crn, course_dept, course_num]
# Index: []
#
# Index: 7957
# PROBLEM: THERE WASN'T ONE MATCH FOR SESSION AND STUDENT'S CRN
# Empty DataFrame
# Columns: [unnamed:_0, encrypted_name, crn, course_dept, course_num]
# Index: []
#
# Index: 7958
# PROBLEM: THERE WASN'T ONE MATCH FOR SESSION AND STUDENT'S CRN
# Empty DataFrame
# Columns: [unnamed:_0, encrypted_name, crn, course_dept, course_num]
# Index: []
#
# Index: 7959
# PROBLEM: THERE WASN'T ONE MATCH FOR SESSION AND STUDENT'S CRN
# Empty DataFrame
# Columns: [unnamed:_0, encrypted_name, crn, course_dept, course_num]
# Index: []
#
# Index: 7960
# PROBLEM: THERE WASN'T ONE MATCH FOR SESSION AND STUDENT'S CRN
# Empty DataFrame
# Columns: [unnamed:_0, encrypted_name, crn, course_dept, course_num]
# Index: []
#
# Index: 7989
# PROBLEM: THERE WASN'T ONE MATCH FOR SESSION AND STUDENT'S CRN
# Empty DataFrame
# Columns: [unnamed:_0, encrypted_name, crn, course_dept, course_num]
# Index: []
#
# Index: 7990
# PROBLEM: THERE WASN'T ONE MATCH FOR SESSION AND STUDENT'S CRN
# Empty DataFrame
# Columns: [unnamed:_0, encrypted_name, crn, course_dept, course_num]
# Index: []
#
# Index: 7991
# PROBLEM: THERE WASN'T ONE MATCH FOR SESSION AND STUDENT'S CRN
# Empty DataFrame
# Columns: [unnamed:_0, encrypted_name, crn, course_dept, course_num]
# Index: []
#
# Index: 7992
# PROBLEM: THERE WASN'T ONE MATCH FOR SESSION AND STUDENT'S CRN
# Empty DataFrame
# Columns: [unnamed:_0, encrypted_name, crn, course_dept, course_num]
# Index: []
#
# Index: 7993
# PROBLEM: THERE WASN'T ONE MATCH FOR SESSION AND STUDENT'S CRN
# Empty DataFrame
# Columns: [unnamed:_0, encrypted_name, crn, course_dept, course_num]
# Index: []
#
# Index: 7994
# PROBLEM: THERE WASN'T ONE MATCH FOR SESSION AND STUDENT'S CRN
# Empty DataFrame
# Columns: [unnamed:_0, encrypted_name, crn, course_dept, course_num]
# Index: []
#
# Index: 7995
# PROBLEM: THERE WASN'T ONE MATCH FOR SESSION AND STUDENT'S CRN
# Empty DataFrame
# Columns: [unnamed:_0, encrypted_name, crn, course_dept, course_num]
# Index: []
#
# Index: 7996
# PROBLEM: THERE WASN'T ONE MATCH FOR SESSION AND STUDENT'S CRN
# Empty DataFrame
# Columns: [unnamed:_0, encrypted_name, crn, course_dept, course_num]
# Index: []
#
# Index: 7997
# PROBLEM: THERE WASN'T ONE MATCH FOR SESSION AND STUDENT'S CRN
# Empty DataFrame
# Columns: [unnamed:_0, encrypted_name, crn, course_dept, course_num]
# Index: []
#
# Index: 7998
# PROBLEM: THERE WASN'T ONE MATCH FOR SESSION AND STUDENT'S CRN
# Empty DataFrame
# Columns: [unnamed:_0, encrypted_name, crn, course_dept, course_num]
# Index: []
#
# Index: 7999
# PROBLEM: THERE WASN'T ONE MATCH FOR SESSION AND STUDENT'S CRN
# Empty DataFrame
# Columns: [unnamed:_0, encrypted_name, crn, course_dept, course_num]
# Index: []
#
# Index: 8016
# PROBLEM: THERE WASN'T ONE MATCH FOR SESSION AND STUDENT'S CRN
# Empty DataFrame
# Columns: [unnamed:_0, encrypted_name, crn, course_dept, course_num]
# Index: []
#
# Index: 8021
# PROBLEM: THERE WASN'T ONE MATCH FOR SESSION AND STUDENT'S CRN
# Empty DataFrame
# Columns: [unnamed:_0, encrypted_name, crn, course_dept, course_num]
# Index: []
#
# Index: 8022
# PROBLEM: THERE WASN'T ONE MATCH FOR SESSION AND STUDENT'S CRN
# Empty DataFrame
# Columns: [unnamed:_0, encrypted_name, crn, course_dept, course_num]
# Index: []
#
# Index: 8025
# PROBLEM: THERE WASN'T ONE MATCH FOR SESSION AND STUDENT'S CRN
# Empty DataFrame
# Columns: [unnamed:_0, encrypted_name, crn, course_dept, course_num]
# Index: []
#
# Index: 8026
# PROBLEM: THERE WASN'T ONE MATCH FOR SESSION AND STUDENT'S CRN
# Empty DataFrame
# Columns: [unnamed:_0, encrypted_name, crn, course_dept, course_num]
# Index: []
#
# Index: 8029
# PROBLEM: THERE WASN'T ONE MATCH FOR SESSION AND STUDENT'S CRN
# Empty DataFrame
# Columns: [unnamed:_0, encrypted_name, crn, course_dept, course_num]
# Index: []
#
# Index: 8030
# PROBLEM: THERE WASN'T ONE MATCH FOR SESSION AND STUDENT'S CRN
# Empty DataFrame
# Columns: [unnamed:_0, encrypted_name, crn, course_dept, course_num]
# Index: []
#
# Index: 8031
# PROBLEM: THERE WASN'T ONE MATCH FOR SESSION AND STUDENT'S CRN
# Empty DataFrame
# Columns: [unnamed:_0, encrypted_name, crn, course_dept, course_num]
# Index: []
#
# Index: 8038
# PROBLEM: THERE WASN'T ONE MATCH FOR SESSION AND STUDENT'S CRN
# Empty DataFrame
# Columns: [unnamed:_0, encrypted_name, crn, course_dept, course_num]
# Index: []
#
# Index: 8039
# PROBLEM: THERE WASN'T ONE MATCH FOR SESSION AND STUDENT'S CRN
# Empty DataFrame
# Columns: [unnamed:_0, encrypted_name, crn, course_dept, course_num]
# Index: []
#
# Index: 8040
# PROBLEM: THERE WASN'T ONE MATCH FOR SESSION AND STUDENT'S CRN
# Empty DataFrame
# Columns: [unnamed:_0, encrypted_name, crn, course_dept, course_num]
# Index: []

# %%
crn_col
# Out:
# 0       96263
# 1       96263
# 2         NaN
# 3       96263
# 4         NaN
#         ...
# 8042      NaN
# 8043      NaN
# 8044      NaN
# 8045      NaN
# 8046      NaN
# Length: 8047, dtype: object

# %%
# Add CRN series to df
df.insert(5, 'crn', crn_col)

# %%
df
# Out:
#         id       encrypted_name                           service course_dept  \
# 0        1               Shayla  In-person Tutoring (STEM Center)        MATH
# 1        2               Shayla  In-person Tutoring (STEM Center)        MATH
# 2        3               Shayla      Space to Study (STEM Center)         NaN
# 3        4               Shayla  In-person Tutoring (STEM Center)        MATH
# 4        5               Shayla      Space to Study (STEM Center)         NaN
# ...    ...                  ...                               ...         ...
# 8042  9696  Non-STEM Registered      Space to Study (STEM Center)         NaN
# 8043  9697  Non-STEM Registered      Space to Study (STEM Center)         NaN
# 8044  9698  Non-STEM Registered      Space to Study (STEM Center)         NaN
# 8045  9699  Non-STEM Registered      Space to Study (STEM Center)         NaN
# 8046  9700  Non-STEM Registered      Space to Study (STEM Center)         NaN
#
#      course_num    crn                                course  \
# 0           252  96263  [MATH-252]Calcu/Analytic Geometry II
# 1           252  96263  [MATH-252]Calcu/Analytic Geometry II
# 2           NaN    NaN                                   NaN
# 3           252  96263  [MATH-252]Calcu/Analytic Geometry II
# 4           NaN    NaN                                   NaN
# ...         ...    ...                                   ...
# 8042        NaN    NaN                                   NaN
# 8043        NaN    NaN                                   NaN
# 8044        NaN    NaN                                   NaN
# 8045        NaN    NaN                                   NaN
# 8046        NaN    NaN                                   NaN
#
#             sign_in_time       sign_out_time  duration  hour_in  hour_out  \
# 0    2022-10-07 09:05:00 2022-10-07 09:16:00  00:11:00        9         9
# 1    2022-10-05 11:17:00 2022-10-05 11:59:00  00:42:00       11        11
# 2    2022-09-28 09:03:00 2022-09-28 10:06:00  01:03:00        9        10
# 3    2022-09-21 09:50:00 2022-09-21 10:05:00  00:15:00        9        10
# 4    2022-09-19 14:11:00 2022-09-19 17:41:00  03:30:00       14        17
# ...                  ...                 ...       ...      ...       ...
# 8042 2022-08-18 14:58:00 2022-08-18 17:53:00  02:55:00       14        17
# 8043 2022-08-18 13:05:00 2022-08-18 13:48:00  00:43:00       13        13
# 8044 2022-08-17 11:03:00 2022-08-17 12:56:00  01:53:00       11        12
# 8045 2022-08-17 10:27:00 2022-08-17 10:50:00  00:23:00       10        10
# 8046 2022-08-17 10:29:00 2022-08-17 10:50:00  00:21:00       10        10
#
#       weekday          tutor
# 0           4  Thiri Wai Wai
# 1           2     Hilary Lin
# 2           2            NaN
# 3           2  Thiri Wai Wai
# 4           0            NaN
# ...       ...            ...
# 8042        3            NaN
# 8043        3            NaN
# 8044        2            NaN
# 8045        2            NaN
# 8046        2
#
# [8047 rows x 14 columns]

# %%
import sqlite3
conn = sqlite3.connect("sessions.db")
df.to_sql(name="sessions", con=conn, if_exists="replace")
# Out:
# 8047

# %%
# Problem here !!!
df[((df['service'] == 'Virtual Tutoring') | (df['service'] == 'In-person Tutoring (STEM Center)')) & (df['course_dept'] == 'LSKL')]
# Out:
#         id       encrypted_name                           service course_dept  \
# 517    725                Joren  In-person Tutoring (STEM Center)        LSKL
# 1145  1494               Simcha  In-person Tutoring (STEM Center)        LSKL
# 1155  1504               Simcha                  Virtual Tutoring        LSKL
# 3327  4052              Ludwina  In-person Tutoring (STEM Center)        LSKL
# 3582  4351              Danzell  In-person Tutoring (STEM Center)        LSKL
# ...    ...                  ...                               ...         ...
# 7908  9561  Non-STEM Registered  In-person Tutoring (STEM Center)        LSKL
# 7909  9562  Non-STEM Registered  In-person Tutoring (STEM Center)        LSKL
# 7910  9563  Non-STEM Registered  In-person Tutoring (STEM Center)        LSKL
# 8021  9675  Non-STEM Registered  In-person Tutoring (STEM Center)        LSKL
# 8022  9676  Non-STEM Registered  In-person Tutoring (STEM Center)        LSKL
#
#      course_num      crn                                  course  \
# 517         803  Dropped    [LSKL-803]Supv. Peer Tutoring - PROM
# 1145        803  Dropped    [LSKL-803]Supv. Peer Tutoring - PROM
# 1155        803  Dropped    [LSKL-803]Supv. Peer Tutoring - PROM
# 3327        803  Dropped    [LSKL-803]Supv. Peer Tutoring - PROM
# 3582        803  Dropped    [LSKL-803]Supv. Peer Tutoring - PROM
# ...         ...      ...                                     ...
# 7908        803  Dropped    [LSKL-803]Supv. Peer Tutoring - PROM
# 7909        803  Dropped    [LSKL-803]Supv. Peer Tutoring - PROM
# 7910        803  Dropped    [LSKL-803]Supv. Peer Tutoring - PROM
# 8021        803  Dropped    [LSKL-803]Supv. Peer Tutoring - PROM
# 8022        800  Dropped  [LSKL-800]Supplemental Learn Assis (1)
#
#             sign_in_time       sign_out_time  duration  hour_in  hour_out  \
# 517  2022-09-19 09:30:00 2022-09-19 10:05:00  00:35:00        9        10
# 1145 2022-11-01 14:46:00 2022-11-01 15:02:00  00:16:00       14        15
# 1155 2022-10-27 13:18:00 2022-10-27 13:30:00  00:12:00       13        13
# 3327 2022-09-14 14:04:00 2022-09-14 14:15:00  00:11:00       14        14
# 3582 2022-11-09 10:17:00 2022-11-09 10:46:00  00:29:00       10        10
# ...                  ...                 ...       ...      ...       ...
# 7908 2022-11-07 15:31:00 2022-11-07 16:36:00  01:05:00       15        16
# 7909 2022-10-26 15:06:00 2022-10-26 15:33:00  00:27:00       15        15
# 7910 2022-10-24 15:00:00 2022-10-24 15:57:00  00:57:00       15        15
# 8021 2022-09-20 16:13:00 2022-09-20 17:54:00  01:41:00       16        17
# 8022 2022-08-30 16:33:00 2022-08-30 17:57:00  01:24:00       16        17
#
#       weekday                  tutor
# 517         0         Bryan Swartout
# 1145        1      John Carlo Manuel
# 1155        3      John Carlo Manuel
# 3327        2            Junior Kyaw
# 3582        2             Hilary Lin
# ...       ...                    ...
# 7908        0     Sebastian Vuskovic
# 7909        2            Chuyun Wang
# 7910        0  Lasheana Dilian Husni
# 8021        1          Emma  Redalen
# 8022        1          Emma  Redalen
#
# [41 rows x 14 columns]

# %%
# Filter registration for info test
df_reg[(df_reg['course_dept'] == 'COMP') & (df_reg['course_num'] == '250')]
# Out:
#       unnamed:_0 encrypted_name    crn course_dept course_num
# 29            29         Tniyah  97583        COMP        250
# 188          188    Condoleezza  97583        COMP        250
# 246          246          Beyda  97584        COMP        250
# 296          296       Quennell  97583        COMP        250
# 365          365        Kindall  97584        COMP        250
# ...          ...            ...    ...         ...        ...
# 2485        2485        Amerigo  97583        COMP        250
# 2551        2551     Latravious  95776        COMP        250
# 2715        2715          Latea  97583        COMP        250
# 2725        2725        Jaydehn  97584        COMP        250
# 2732        2732       Javontez  97584        COMP        250
#
# [56 rows x 5 columns]

# %%
df['course'].value_counts()
# Out:
# [BIOL-240]General Microbiology              1949
# [BIOL-230]Introduction to Cell Biology       229
# [MATH-251]Calculus/Analytic Geometry I       170
# [PHYS-250]Physics with Calculus I            114
# [CHEM-410]Chem For Health Sciences            99
#                                             ...
# [HIST-240]History of Ethnic Groups in CA       1
# [CHEM-235]Organic Chemistry II                 1
# [CHEM-237]Organic Chemistry Lab I              1
# [BIOL-130]Human Biology                        1
# [LSKL-800]Supplemental Learn Assis (1)         1
# Name: course, Length: 48, dtype: int64

# %%
# Check if session logs data was gathered after withdraw deadline (11/15/22)
# Turns out data was gathered on 11/10/22
df[df['sign_in_time'].dt.month == 11].sort_values(by='sign_in_time', ascending=False)
# Out:
#         id       encrypted_name                       service course_dept  \
# 7840  9488  Non-STEM Registered  Space to Study (STEM Center)         NaN
# 702    955               Demaya  Space to Study (STEM Center)         NaN
# 278    397              Coulson          Open Lab (TBA Hours)        BIOL
# 110    129                Chess          Open Lab (TBA Hours)        BIOL
# 4959  5968                 Naly          Open Lab (TBA Hours)        BIOL
# ...    ...                  ...                           ...         ...
# 1149  1498               Simcha  Space to Study (STEM Center)         NaN
# 3382  4126              Cheresa  Space to Study (STEM Center)         NaN
# 2799  3464          Victorianna  Space to Study (STEM Center)         NaN
# 5722  6906               Jalend  Space to Study (STEM Center)         NaN
# 2018  2539                Jerey  Space to Study (STEM Center)         NaN
#
#      course_num    crn                          course        sign_in_time  \
# 7840        NaN    NaN                             NaN 2022-11-10 19:08:00
# 702         NaN    NaN                             NaN 2022-11-10 19:07:00
# 278         240  84531  [BIOL-240]General Microbiology 2022-11-10 18:20:00
# 110         240  84531  [BIOL-240]General Microbiology 2022-11-10 18:19:00
# 4959        240  84531  [BIOL-240]General Microbiology 2022-11-10 18:18:00
# ...         ...    ...                             ...                 ...
# 1149        NaN    NaN                             NaN 2022-11-01 09:02:00
# 3382        NaN    NaN                             NaN 2022-11-01 09:02:00
# 2799        NaN    NaN                             NaN 2022-11-01 08:37:00
# 5722        NaN    NaN                             NaN 2022-11-01 08:19:00
# 2018        NaN    NaN                             NaN 2022-11-01 08:08:00
#
#            sign_out_time  duration  hour_in  hour_out  weekday tutor
# 7840 2022-11-10 19:41:00  00:33:00       19        19        3   NaN
# 702  2022-11-10 19:25:00  00:18:00       19        19        3   NaN
# 278  2022-11-10 19:08:00  00:48:00       18        19        3   NaN
# 110  2022-11-10 19:21:00  01:02:00       18        19        3   NaN
# 4959 2022-11-10 19:04:00  00:46:00       18        19        3   NaN
# ...                  ...       ...      ...       ...      ...   ...
# 1149 2022-11-01 09:35:00  00:33:00        9         9        1   NaN
# 3382 2022-11-01 12:32:00  03:30:00        9        12        1   NaN
# 2799 2022-11-01 08:57:00  00:20:00        8         8        1   NaN
# 5722 2022-11-01 09:06:00  00:47:00        8         9        1   NaN
# 2018 2022-11-01 09:34:00  01:26:00        8         9        1   NaN
#
# [1155 rows x 14 columns]

# %%
def make_df_week():
    d = {
        'M'  : [0] * 13,
        'T'  : [0] * 13,
        'W'  : [0] * 13,
        'Th' : [0] * 13,
        'F'  : [0] * 13,
    }
    df = pd.DataFrame(d)
    df.index += 8
    return df

# %%
def get_filter(services):
    filt = [False] * df.shape[0]
    for service in services:
        filt = filt | (df['service'] == service)
    return filt

# %%
def make_df_with_filter(services):
    filt = get_filter(services)
    filt_df = df[filt]
    filt_df.reset_index(drop=True, inplace=True)
    
    df_week = make_df_week()
    
    for i in range(filt_df.shape[0]):
        hour_in  = filt_df['hour_in'][i]
        hour_out = filt_df['hour_out'][i]
        weekday = filt_df['weekday'][i]
        
        for hour in range(hour_in, hour_out + 1):
            df_week.loc[hour][weekday] += 1
    return df_week
